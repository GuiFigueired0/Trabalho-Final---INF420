# %% [markdown]
# ## Importando as dependências

# %%
# Python
import time
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Classificadores
from sktime.classification.kernel_based import RocketClassifier
from sktime.classification.interval_based import TimeSeriesForestClassifier

# Grid Search
from sktime.classification.model_selection import TSCGridSearchCV

# Auxiliares
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, matthews_corrcoef, classification_report, multilabel_confusion_matrix

# %% [markdown]
# ## Importando o dataset

# %%
raw_csv_data = pd.read_csv('time_series.csv') 
df: pd.DataFrame = raw_csv_data.copy()

# %%
df.head()
# Out:
#    id            timestamp        date  activity        owner gender  \
# 0   0  2003-05-08 00:00:00  2003-05-08         0  condition_1   male
# 1   0  2003-05-08 00:01:00  2003-05-08         0  condition_1   male
# 2   0  2003-05-08 00:02:00  2003-05-08         0  condition_1   male
# 3   0  2003-05-08 00:03:00  2003-05-08         0  condition_1   male
# 4   0  2003-05-08 00:04:00  2003-05-08         0  condition_1   male
#
#           melanch   inpatient               marriage  \
# 0  no melancholia  outpatient  married or cohabiting
# 1  no melancholia  outpatient  married or cohabiting
# 2  no melancholia  outpatient  married or cohabiting
# 3  no melancholia  outpatient  married or cohabiting
# 4  no melancholia  outpatient  married or cohabiting
#
#                             work              afftype binary_class
# 0  unemployed/sick leave/pension  unipolar depressive    depressed
# 1  unemployed/sick leave/pension  unipolar depressive    depressed
# 2  unemployed/sick leave/pension  unipolar depressive    depressed
# 3  unemployed/sick leave/pension  unipolar depressive    depressed
# 4  unemployed/sick leave/pension  unipolar depressive    depressed

# %% [markdown]
# ## Funções auxiliares

# %%
def to_2D_array(df, n_days, variable):
    n_users = len(df.id.unique())
    arr = df[variable].values.reshape(n_users, n_days)
    return arr

# %%
def find_best_hyperparameters(clf, param_grid, X, y):
    grid = TSCGridSearchCV(estimator=clf, param_grid=param_grid, scoring='f1_weighted', cv=10, verbose=5)
    grid.fit(X, y)
    results_df = pd.DataFrame(grid.cv_results_)
    return results_df

# %% [markdown]
# ## Seperando o dataset entre X e y (features e classe)

# %%
X = to_2D_array(df, 1440, 'activity')
y = df.iloc[[ i*1440 for i in range(1029) ], -1].values
print('Formato X:', X.shape)
print('Formato y:', y.shape)
# Out:
# Formato X: (1029, 1440)
# Formato y: (1029,)

# %% [markdown]
# # TSF

# %%
tsf = TimeSeriesForestClassifier()

# %%
parameters = {  
    'random_state': [42],
    'min_interval': [3, 5, 10, 15, 20, 30, 45, 60], 
}

# %%
tsf_grid_min_interval = find_best_hyperparameters(tsf, parameters, X, y)
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [CV 1/10] END ..min_interval=3, random_state=42;, score=0.650 total time=  41.7s
# [CV 2/10] END ..min_interval=3, random_state=42;, score=0.712 total time=  46.2s
# [CV 3/10] END ..min_interval=3, random_state=42;, score=0.691 total time=  44.3s
# [CV 4/10] END ..min_interval=3, random_state=42;, score=0.704 total time=  44.9s
# [CV 5/10] END ..min_interval=3, random_state=42;, score=0.630 total time=  44.1s
# [CV 6/10] END ..min_interval=3, random_state=42;, score=0.814 total time=  50.8s
# [CV 7/10] END ..min_interval=3, random_state=42;, score=0.642 total time=  45.9s
# [CV 8/10] END ..min_interval=3, random_state=42;, score=0.905 total time=  46.8s
# [CV 9/10] END ..min_interval=3, random_state=42;, score=0.856 total time=  47.5s
# [CV 10/10] END .min_interval=3, random_state=42;, score=0.662 total time=  46.4s
# [CV 1/10] END ..min_interval=5, random_state=42;, score=0.630 total time=  45.9s
# [CV 2/10] END ..min_interval=5, random_state=42;, score=0.696 total time=  45.4s
# [CV 3/10] END ..min_interval=5, random_state=42;, score=0.729 total time=  46.6s
# [CV 4/10] END ..min_interval=5, random_state=42;, score=0.682 total time=  45.5s
# [CV 5/10] END ..min_interval=5, random_state=42;, score=0.611 total time=  45.1s
# [CV 6/10] END ..min_interval=5, random_state=42;, score=0.823 total time=  46.1s
# [CV 7/10] END ..min_interval=5, random_state=42;, score=0.620 total time=  50.2s
# [CV 8/10] END ..min_interval=5, random_state=42;, score=0.885 total time=  46.7s
# [CV 9/10] END ..min_interval=5, random_state=42;, score=0.865 total time=  46.7s
# [CV 10/10] END .min_interval=5, random_state=42;, score=0.691 total time=  45.7s
# [CV 1/10] END .min_interval=10, random_state=42;, score=0.634 total time=  45.3s
# [CV 2/10] END .min_interval=10, random_state=42;, score=0.687 total time=  45.2s
# [CV 3/10] END .min_interval=10, random_state=42;, score=0.717 total time=  45.9s
# [CV 4/10] END .min_interval=10, random_state=42;, score=0.718 total time=  44.9s
# [CV 5/10] END .min_interval=10, random_state=42;, score=0.611 total time=  44.6s
# [CV 6/10] END .min_interval=10, random_state=42;, score=0.812 total time=  45.5s
# [CV 7/10] END .min_interval=10, random_state=42;, score=0.648 total time=  45.5s
# [CV 8/10] END .min_interval=10, random_state=42;, score=0.867 total time=  46.1s
# [CV 9/10] END .min_interval=10, random_state=42;, score=0.856 total time=  46.3s
# [CV 10/10] END min_interval=10, random_state=42;, score=0.683 total time=  45.9s
# [CV 1/10] END .min_interval=15, random_state=42;, score=0.622 total time=  45.5s
# [CV 2/10] END .min_interval=15, random_state=42;, score=0.717 total time=  45.5s
# [CV 3/10] END .min_interval=15, random_state=42;, score=0.699 total time=  45.8s
# [CV 4/10] END .min_interval=15, random_state=42;, score=0.687 total time=  45.1s
# [CV 5/10] END .min_interval=15, random_state=42;, score=0.592 total time=  44.7s
# [CV 6/10] END .min_interval=15, random_state=42;, score=0.790 total time=  45.5s
# [CV 7/10] END .min_interval=15, random_state=42;, score=0.628 total time=  48.4s
# [CV 8/10] END .min_interval=15, random_state=42;, score=0.858 total time=  49.4s
# [CV 9/10] END .min_interval=15, random_state=42;, score=0.856 total time=  49.3s
# [CV 10/10] END min_interval=15, random_state=42;, score=0.688 total time=  49.1s
# [CV 1/10] END .min_interval=20, random_state=42;, score=0.650 total time=  48.7s
# [CV 2/10] END .min_interval=20, random_state=42;, score=0.721 total time=  49.1s
# [CV 3/10] END .min_interval=20, random_state=42;, score=0.677 total time=  49.1s
# [CV 4/10] END .min_interval=20, random_state=42;, score=0.638 total time=  48.2s
# [CV 5/10] END .min_interval=20, random_state=42;, score=0.621 total time=  48.2s
# [CV 6/10] END .min_interval=20, random_state=42;, score=0.779 total time=  48.2s
# [CV 7/10] END .min_interval=20, random_state=42;, score=0.642 total time=  46.9s
# [CV 8/10] END .min_interval=20, random_state=42;, score=0.867 total time=  50.0s
# [CV 9/10] END .min_interval=20, random_state=42;, score=0.856 total time=  49.3s
# [CV 10/10] END min_interval=20, random_state=42;, score=0.708 total time=  49.3s
# [CV 1/10] END .min_interval=30, random_state=42;, score=0.646 total time=  49.0s
# [CV 2/10] END .min_interval=30, random_state=42;, score=0.717 total time=  48.0s
# [CV 3/10] END .min_interval=30, random_state=42;, score=0.712 total time=  48.2s
# [CV 4/10] END .min_interval=30, random_state=42;, score=0.682 total time=  45.9s
# [CV 5/10] END .min_interval=30, random_state=42;, score=0.630 total time=  44.7s
# [CV 6/10] END .min_interval=30, random_state=42;, score=0.783 total time=  44.9s
# [CV 7/10] END .min_interval=30, random_state=42;, score=0.642 total time=  46.0s
# [CV 8/10] END .min_interval=30, random_state=42;, score=0.895 total time=  46.5s
# [CV 9/10] END .min_interval=30, random_state=42;, score=0.866 total time=  46.4s
# [CV 10/10] END min_interval=30, random_state=42;, score=0.692 total time=  46.3s
# [CV 1/10] END .min_interval=45, random_state=42;, score=0.642 total time=  46.1s
# [CV 2/10] END .min_interval=45, random_state=42;, score=0.729 total time=  46.3s
# [CV 3/10] END .min_interval=45, random_state=42;, score=0.762 total time=  46.6s
# [CV 4/10] END .min_interval=45, random_state=42;, score=0.685 total time=  45.9s
# [CV 5/10] END .min_interval=45, random_state=42;, score=0.602 total time=  45.4s
# [CV 6/10] END .min_interval=45, random_state=42;, score=0.803 total time=  45.7s
# [CV 7/10] END .min_interval=45, random_state=42;, score=0.642 total time=  45.8s
# [CV 8/10] END .min_interval=45, random_state=42;, score=0.914 total time=  47.0s
# [CV 9/10] END .min_interval=45, random_state=42;, score=0.856 total time=  46.6s
# [CV 10/10] END min_interval=45, random_state=42;, score=0.708 total time=  47.0s
# [CV 1/10] END .min_interval=60, random_state=42;, score=0.638 total time=  46.8s
# [CV 2/10] END .min_interval=60, random_state=42;, score=0.717 total time=  46.7s
# [CV 3/10] END .min_interval=60, random_state=42;, score=0.741 total time=  47.0s
# [CV 4/10] END .min_interval=60, random_state=42;, score=0.685 total time=  46.0s
# [CV 5/10] END .min_interval=60, random_state=42;, score=0.583 total time=  45.8s
# [CV 6/10] END .min_interval=60, random_state=42;, score=0.772 total time=  48.2s
# [CV 7/10] END .min_interval=60, random_state=42;, score=0.648 total time=  47.7s
# [CV 8/10] END .min_interval=60, random_state=42;, score=0.904 total time=  49.1s
# [CV 9/10] END .min_interval=60, random_state=42;, score=0.875 total time=  48.8s
# [CV 10/10] END min_interval=60, random_state=42;, score=0.671 total time=  49.0s
# c:\Users\guilh\GitHub\Trabalho-Final---INF420\venv\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
parameters = {  
    'random_state': [42],
    'inner_series_length': [60, 360, 720, 180, 1440]
}

# %%
tsf_grid_inner_series_length = find_best_hyperparameters(tsf, parameters, X, y)
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# [CV 1/10] END inner_series_length=60, random_state=42;, score=0.720 total time=  19.9s
# [CV 2/10] END inner_series_length=60, random_state=42;, score=0.680 total time=  19.9s
# [CV 3/10] END inner_series_length=60, random_state=42;, score=0.737 total time=  19.9s
# [CV 4/10] END inner_series_length=60, random_state=42;, score=0.655 total time=  19.4s
# [CV 5/10] END inner_series_length=60, random_state=42;, score=0.640 total time=  18.4s
# [CV 6/10] END inner_series_length=60, random_state=42;, score=0.803 total time=  19.0s
# [CV 7/10] END inner_series_length=60, random_state=42;, score=0.576 total time=  20.3s
# [CV 8/10] END inner_series_length=60, random_state=42;, score=0.923 total time=  19.5s
# [CV 9/10] END inner_series_length=60, random_state=42;, score=0.902 total time=  20.2s
# [CV 10/10] END inner_series_length=60, random_state=42;, score=0.649 total time=  21.1s
# [CV 1/10] END inner_series_length=360, random_state=42;, score=0.704 total time=  24.7s
# [CV 2/10] END inner_series_length=360, random_state=42;, score=0.707 total time=  25.3s
# [CV 3/10] END inner_series_length=360, random_state=42;, score=0.785 total time=  25.2s
# [CV 4/10] END inner_series_length=360, random_state=42;, score=0.647 total time=  24.1s
# [CV 5/10] END inner_series_length=360, random_state=42;, score=0.630 total time=  24.1s
# [CV 6/10] END inner_series_length=360, random_state=42;, score=0.770 total time=  24.1s
# [CV 7/10] END inner_series_length=360, random_state=42;, score=0.620 total time=  24.5s
# [CV 8/10] END inner_series_length=360, random_state=42;, score=0.904 total time=  24.4s
# [CV 9/10] END inner_series_length=360, random_state=42;, score=0.836 total time=  24.6s
# [CV 10/10] END inner_series_length=360, random_state=42;, score=0.683 total time=  24.9s
# [CV 1/10] END inner_series_length=720, random_state=42;, score=0.682 total time=  29.7s
# [CV 2/10] END inner_series_length=720, random_state=42;, score=0.687 total time=  29.4s
# [CV 3/10] END inner_series_length=720, random_state=42;, score=0.785 total time=  30.5s
# [CV 4/10] END inner_series_length=720, random_state=42;, score=0.679 total time=  29.2s
# [CV 5/10] END inner_series_length=720, random_state=42;, score=0.620 total time=  29.1s
# [CV 6/10] END inner_series_length=720, random_state=42;, score=0.750 total time=  29.5s
# [CV 7/10] END inner_series_length=720, random_state=42;, score=0.620 total time=  29.7s
# [CV 8/10] END inner_series_length=720, random_state=42;, score=0.905 total time=  31.1s
# [CV 9/10] END inner_series_length=720, random_state=42;, score=0.799 total time=  31.0s
# [CV 10/10] END inner_series_length=720, random_state=42;, score=0.679 total time=  31.9s
# [CV 1/10] END inner_series_length=180, random_state=42;, score=0.712 total time=  21.4s
# [CV 2/10] END inner_series_length=180, random_state=42;, score=0.680 total time=  21.7s
# [CV 3/10] END inner_series_length=180, random_state=42;, score=0.780 total time=  22.0s
# [CV 4/10] END inner_series_length=180, random_state=42;, score=0.647 total time=  21.7s
# [CV 5/10] END inner_series_length=180, random_state=42;, score=0.590 total time=  20.6s
# [CV 6/10] END inner_series_length=180, random_state=42;, score=0.764 total time=  21.4s
# [CV 7/10] END inner_series_length=180, random_state=42;, score=0.577 total time=  21.9s
# [CV 8/10] END inner_series_length=180, random_state=42;, score=0.914 total time=  21.6s
# [CV 9/10] END inner_series_length=180, random_state=42;, score=0.816 total time=  21.2s
# [CV 10/10] END inner_series_length=180, random_state=42;, score=0.692 total time=  21.3s
# [CV 1/10] END inner_series_length=1440, random_state=42;, score=0.650 total time=  42.3s
# [CV 2/10] END inner_series_length=1440, random_state=42;, score=0.712 total time=  40.2s
# [CV 3/10] END inner_series_length=1440, random_state=42;, score=0.691 total time=  40.7s
# [CV 4/10] END inner_series_length=1440, random_state=42;, score=0.704 total time=  39.8s
# [CV 5/10] END inner_series_length=1440, random_state=42;, score=0.630 total time=  39.4s
# [CV 6/10] END inner_series_length=1440, random_state=42;, score=0.814 total time=  40.7s
# [CV 7/10] END inner_series_length=1440, random_state=42;, score=0.642 total time=  46.5s
# [CV 8/10] END inner_series_length=1440, random_state=42;, score=0.905 total time=  42.4s
# [CV 9/10] END inner_series_length=1440, random_state=42;, score=0.856 total time=  42.4s
# [CV 10/10] END inner_series_length=1440, random_state=42;, score=0.662 total time=  41.9s

# %%
parameters = {  
    'random_state': [42],
    'n_estimators': [100, 200, 500, 750, 1000],
}

# %%
tsf_grid_n_estimators = find_best_hyperparameters(tsf, parameters, X, y)
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# [CV 1/10] END n_estimators=100, random_state=42;, score=0.638 total time=  21.7s
# [CV 2/10] END n_estimators=100, random_state=42;, score=0.700 total time=  21.2s
# [CV 3/10] END n_estimators=100, random_state=42;, score=0.699 total time=  21.9s
# [CV 4/10] END n_estimators=100, random_state=42;, score=0.696 total time=  20.8s
# [CV 5/10] END n_estimators=100, random_state=42;, score=0.611 total time=  20.8s
# [CV 6/10] END n_estimators=100, random_state=42;, score=0.801 total time=  21.1s
# [CV 7/10] END n_estimators=100, random_state=42;, score=0.628 total time=  20.6s
# [CV 8/10] END n_estimators=100, random_state=42;, score=0.895 total time=  20.8s
# [CV 9/10] END n_estimators=100, random_state=42;, score=0.865 total time=  21.2s
# [CV 10/10] END n_estimators=100, random_state=42;, score=0.662 total time=  21.1s
# [CV 1/10] END n_estimators=200, random_state=42;, score=0.650 total time=  41.2s
# [CV 2/10] END n_estimators=200, random_state=42;, score=0.712 total time=  41.5s
# [CV 3/10] END n_estimators=200, random_state=42;, score=0.691 total time=  44.4s
# [CV 4/10] END n_estimators=200, random_state=42;, score=0.704 total time=  42.3s
# [CV 5/10] END n_estimators=200, random_state=42;, score=0.630 total time=  41.1s
# [CV 6/10] END n_estimators=200, random_state=42;, score=0.814 total time=  41.0s
# [CV 7/10] END n_estimators=200, random_state=42;, score=0.642 total time=  41.4s
# [CV 8/10] END n_estimators=200, random_state=42;, score=0.905 total time=  43.1s
# [CV 9/10] END n_estimators=200, random_state=42;, score=0.856 total time=  46.9s
# [CV 10/10] END n_estimators=200, random_state=42;, score=0.662 total time=  42.3s
# [CV 1/10] END n_estimators=500, random_state=42;, score=0.655 total time= 1.8min
# [CV 2/10] END n_estimators=500, random_state=42;, score=0.708 total time= 1.8min
# [CV 3/10] END n_estimators=500, random_state=42;, score=0.712 total time= 1.8min
# [CV 4/10] END n_estimators=500, random_state=42;, score=0.715 total time= 1.8min
# [CV 5/10] END n_estimators=500, random_state=42;, score=0.630 total time= 1.8min
# [CV 6/10] END n_estimators=500, random_state=42;, score=0.801 total time= 2.0min
# [CV 7/10] END n_estimators=500, random_state=42;, score=0.650 total time= 1.8min
# [CV 8/10] END n_estimators=500, random_state=42;, score=0.895 total time= 2.0min
# [CV 9/10] END n_estimators=500, random_state=42;, score=0.856 total time= 1.9min
# [CV 10/10] END n_estimators=500, random_state=42;, score=0.675 total time= 1.8min
# [CV 1/10] END n_estimators=750, random_state=42;, score=0.658 total time= 2.7min
# [CV 2/10] END n_estimators=750, random_state=42;, score=0.696 total time= 2.6min
# [CV 3/10] END n_estimators=750, random_state=42;, score=0.750 total time= 2.6min
# [CV 4/10] END n_estimators=750, random_state=42;, score=0.693 total time= 2.7min
# [CV 5/10] END n_estimators=750, random_state=42;, score=0.630 total time= 2.7min
# [CV 6/10] END n_estimators=750, random_state=42;, score=0.790 total time= 2.6min
# [CV 7/10] END n_estimators=750, random_state=42;, score=0.650 total time= 2.6min
# [CV 8/10] END n_estimators=750, random_state=42;, score=0.895 total time= 2.6min
# [CV 9/10] END n_estimators=750, random_state=42;, score=0.866 total time= 2.6min
# [CV 10/10] END n_estimators=750, random_state=42;, score=0.678 total time= 2.6min
# [CV 1/10] END n_estimators=1000, random_state=42;, score=0.658 total time= 3.5min
# [CV 2/10] END n_estimators=1000, random_state=42;, score=0.696 total time= 3.5min
# [CV 3/10] END n_estimators=1000, random_state=42;, score=0.712 total time= 3.6min
# [CV 4/10] END n_estimators=1000, random_state=42;, score=0.715 total time= 3.5min
# [CV 5/10] END n_estimators=1000, random_state=42;, score=0.621 total time= 3.4min
# [CV 6/10] END n_estimators=1000, random_state=42;, score=0.790 total time= 3.4min
# [CV 7/10] END n_estimators=1000, random_state=42;, score=0.650 total time= 3.5min
# [CV 8/10] END n_estimators=1000, random_state=42;, score=0.895 total time= 3.6min
# [CV 9/10] END n_estimators=1000, random_state=42;, score=0.866 total time= 3.5min
# [CV 10/10] END n_estimators=1000, random_state=42;, score=0.670 total time= 3.7min

# %%
display(tsf_grid_min_interval.sort_values(by='rank_test_score').head())
display(tsf_grid_inner_series_length.sort_values(by='rank_test_score').head())
display(tsf_grid_n_estimators.sort_values(by='rank_test_score').head())
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6      44.163174      0.529419         2.164575        0.018120
# 0      43.758060      2.253319         2.204832        0.112461
# 5      44.557225      1.324236         2.139910        0.015831
# 7      45.413552      1.135674         2.201952        0.028246
# 2      43.485074      0.528298         2.142159        0.032162
#
#    param_min_interval  param_random_state  \
# 6                  45                  42
# 0                   3                  42
# 5                  30                  42
# 7                  60                  42
# 2                  10                  42
#
#                                      params  split0_test_score  \
# 6  {'min_interval': 45, 'random_state': 42}           0.642445
# 0   {'min_interval': 3, 'random_state': 42}           0.650459
# 5  {'min_interval': 30, 'random_state': 42}           0.645676
# 7  {'min_interval': 60, 'random_state': 42}           0.638486
# 2  {'min_interval': 10, 'random_state': 42}           0.634435
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 6           0.729047           0.761972           0.684685           0.601637
# 0           0.712143           0.690783           0.704393           0.630137
# 5           0.716567           0.712108           0.681856           0.630013
# 7           0.716567           0.741274           0.684685           0.582667
# 2           0.687361           0.716567           0.717507           0.611169
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 6           0.802928           0.642077           0.914330           0.855614
# 0           0.813544           0.642077           0.904685           0.855614
# 5           0.783221           0.642077           0.895292           0.865563
# 7           0.772383           0.648132           0.904371           0.874865
# 2           0.811969           0.648132           0.866885           0.855614
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 6           0.708374         0.734311        0.095030                1
# 0           0.661897         0.726573        0.091835                2
# 5           0.691585         0.726396        0.088053                3
# 7           0.671024         0.723446        0.097663                4
# 2           0.683029         0.723267        0.086659                5
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1      23.581660      0.378417         1.105592        0.063473
# 0      19.038085      0.647240         0.822600        0.064889
# 4      39.641299      1.911688         2.083875        0.215875
# 2      28.754553      0.782024         1.457465        0.157094
# 3      20.665663      0.375385         0.912276        0.021147
#
#    param_inner_series_length  param_random_state  \
# 1                        360                  42
# 0                         60                  42
# 4                       1440                  42
# 2                        720                  42
# 3                        180                  42
#
#                                               params  split0_test_score  \
# 1   {'inner_series_length': 360, 'random_state': 42}           0.703740
# 0    {'inner_series_length': 60, 'random_state': 42}           0.720448
# 4  {'inner_series_length': 1440, 'random_state': 42}           0.650459
# 2   {'inner_series_length': 720, 'random_state': 42}           0.681856
# 3   {'inner_series_length': 180, 'random_state': 42}           0.712143
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 1           0.707154           0.784960           0.646616           0.630137
# 0           0.679553           0.737311           0.654744           0.639576
# 4           0.712143           0.690783           0.704393           0.630137
# 2           0.687361           0.785467           0.678654           0.620355
# 3           0.679553           0.779552           0.646616           0.589809
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 1           0.770218           0.620385           0.903974           0.836363
# 0           0.803368           0.575917           0.923497           0.902240
# 4           0.813544           0.642077           0.904685           0.855614
# 2           0.750237           0.620385           0.904918           0.798785
# 3           0.763514           0.577000           0.914084           0.816104
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 1           0.683029         0.728657        0.088634                1
# 0           0.648638         0.728529        0.109252                2
# 4           0.661897         0.726573        0.091835                3
# 2           0.679275         0.720729        0.084461                4
# 3           0.691585         0.716996        0.098764                5
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3     151.463915      2.932755         7.746858        0.242159
# 2     105.271997      4.540337         5.325963        0.331130
# 4     200.591126      5.425059        10.177572        0.111062
# 1      40.593810      1.775137         2.035832        0.051930
# 0      20.205948      0.386683         1.024237        0.026761
#
#    param_n_estimators  param_random_state  \
# 3                 750                  42
# 2                 500                  42
# 4                1000                  42
# 1                 200                  42
# 0                 100                  42
#
#                                        params  split0_test_score  \
# 3   {'n_estimators': 750, 'random_state': 42}           0.658481
# 2   {'n_estimators': 500, 'random_state': 42}           0.654744
# 4  {'n_estimators': 1000, 'random_state': 42}           0.658481
# 1   {'n_estimators': 200, 'random_state': 42}           0.650459
# 0   {'n_estimators': 100, 'random_state': 42}           0.637783
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 3           0.695572           0.749889           0.693212           0.630013
# 2           0.708204           0.712108           0.715409           0.630013
# 4           0.695572           0.712108           0.715409           0.620626
# 1           0.712143           0.690783           0.704393           0.630137
# 0           0.699878           0.698944           0.695782           0.611169
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 3           0.790199           0.649748           0.895292           0.865563
# 2           0.801160           0.649748           0.894992           0.856275
# 4           0.790199           0.649748           0.895292           0.865563
# 1           0.813544           0.642077           0.904685           0.855614
# 0           0.801160           0.627858           0.895292           0.864885
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 3           0.677996         0.730597        0.087470                1
# 2           0.674859         0.729751        0.086244                2
# 4           0.669933         0.727293        0.088371                3
# 1           0.661897         0.726573        0.091835                4
# 0           0.661897         0.719465        0.094978                5

# %%
parameters = {  
    'random_state': [42],
    'min_interval': [3, 45],
    'inner_series_length': [60, 360], 
    'n_estimators': [500, 750],
}

# %%
tsf_grid = find_best_hyperparameters(tsf, parameters, X, y)
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [CV 1/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.720 total time=  47.7s
# [CV 2/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.673 total time=  47.9s
# [CV 3/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.746 total time=  47.3s
# [CV 4/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.647 total time=  46.6s
# [CV 5/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.649 total time=  46.2s
# [CV 6/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.785 total time=  47.8s
# [CV 7/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.569 total time=  48.6s
# [CV 8/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.905 total time=  48.8s
# [CV 9/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.901 total time=  48.4s
# [CV 10/10] END inner_series_length=60, min_interval=3, n_estimators=500, random_state=42;, score=0.675 total time=  49.1s
# [CV 1/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.733 total time= 1.2min
# [CV 2/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.688 total time= 1.2min
# [CV 3/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.732 total time= 1.2min
# [CV 4/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.642 total time= 1.2min
# [CV 5/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.649 total time= 1.2min
# [CV 6/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.774 total time= 1.2min
# [CV 7/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.576 total time= 1.2min
# [CV 8/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.895 total time= 1.2min
# [CV 9/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.892 total time= 1.2min
# [CV 10/10] END inner_series_length=60, min_interval=3, n_estimators=750, random_state=42;, score=0.683 total time= 1.2min
# [CV 1/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.745 total time=  58.6s
# [CV 2/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.729 total time=  57.3s
# [CV 3/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.763 total time=  57.7s
# [CV 4/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.679 total time=  56.1s
# [CV 5/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.592 total time=  55.7s
# [CV 6/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.748 total time=  58.3s
# [CV 7/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.621 total time=  58.5s
# [CV 8/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.867 total time=  58.3s
# [CV 9/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.875 total time= 1.0min
# [CV 10/10] END inner_series_length=60, min_interval=45, n_estimators=500, random_state=42;, score=0.704 total time= 1.0min
# [CV 1/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.756 total time= 1.5min
# [CV 2/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.712 total time= 1.5min
# [CV 3/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.751 total time= 1.5min
# [CV 4/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.659 total time= 1.4min
# [CV 5/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.611 total time= 1.4min
# [CV 6/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.736 total time= 1.5min
# [CV 7/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.605 total time= 1.5min
# [CV 8/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.839 total time= 1.5min
# [CV 9/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.865 total time= 1.5min
# [CV 10/10] END inner_series_length=60, min_interval=45, n_estimators=750, random_state=42;, score=0.727 total time= 1.5min
# [CV 1/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.724 total time= 1.0min
# [CV 2/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.729 total time= 1.0min
# [CV 3/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.776 total time= 1.1min
# [CV 4/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.647 total time= 1.0min
# [CV 5/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.602 total time=  59.7s
# [CV 6/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.761 total time=  59.9s
# [CV 7/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.591 total time= 1.0min
# [CV 8/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.895 total time= 1.0min
# [CV 9/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.836 total time= 1.0min
# [CV 10/10] END inner_series_length=360, min_interval=3, n_estimators=500, random_state=42;, score=0.704 total time= 1.0min
# [CV 1/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.721 total time= 1.5min
# [CV 2/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.720 total time= 1.7min
# [CV 3/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.776 total time= 1.9min
# [CV 4/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.659 total time= 6.5min
# [CV 5/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.640 total time= 1.8min
# [CV 6/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.761 total time= 1.9min
# [CV 7/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.584 total time= 1.9min
# [CV 8/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.885 total time= 1.9min
# [CV 9/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.826 total time= 1.9min
# [CV 10/10] END inner_series_length=360, min_interval=3, n_estimators=750, random_state=42;, score=0.704 total time= 1.9min
# [CV 1/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.716 total time= 1.3min
# [CV 2/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.694 total time= 1.3min
# [CV 3/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.785 total time= 1.4min
# [CV 4/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.670 total time= 1.3min
# [CV 5/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.621 total time= 1.3min
# [CV 6/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.764 total time= 1.3min
# [CV 7/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.606 total time= 1.3min
# [CV 8/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.895 total time= 1.3min
# [CV 9/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.835 total time= 1.3min
# [CV 10/10] END inner_series_length=360, min_interval=45, n_estimators=500, random_state=42;, score=0.717 total time= 1.3min
# [CV 1/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.748 total time= 2.0min
# [CV 2/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.694 total time= 2.0min
# [CV 3/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.772 total time= 2.1min
# [CV 4/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.650 total time= 2.0min
# [CV 5/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.583 total time= 2.0min
# [CV 6/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.755 total time= 2.0min
# [CV 7/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.599 total time= 2.0min
# [CV 8/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.895 total time= 2.0min
# [CV 9/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.826 total time= 2.0min
# [CV 10/10] END inner_series_length=360, min_interval=45, n_estimators=750, random_state=42;, score=0.717 total time= 2.0min

# %%
display(tsf_grid.sort_values(by='rank_test_score').head())
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2      56.232280      1.778592         2.211766        0.069836
# 6      75.742151      1.300069         3.355748        0.128557
# 5     132.334918     83.737551         4.760060        0.352423
# 0      46.040288      0.876946         1.907623        0.051200
# 4      58.418357      1.072893         2.670229        0.058716
#
#    param_inner_series_length  param_min_interval  param_n_estimators  \
# 2                         60                  45                 500
# 6                        360                  45                 500
# 5                        360                   3                 750
# 0                         60                   3                 500
# 4                        360                   3                 500
#
#    param_random_state                                             params  \
# 2                  42  {'inner_series_length': 60, 'min_interval': 45...
# 6                  42  {'inner_series_length': 360, 'min_interval': 4...
# 5                  42  {'inner_series_length': 360, 'min_interval': 3...
# 0                  42  {'inner_series_length': 60, 'min_interval': 3,...
# 4                  42  {'inner_series_length': 360, 'min_interval': 3...
#
#    split0_test_score  ...  split3_test_score  split4_test_score  \
# 2           0.744604  ...           0.678654           0.592202
# 6           0.715671  ...           0.670313           0.620607
# 5           0.720576  ...           0.658570           0.639576
# 0           0.720448  ...           0.646616           0.649104
# 4           0.724172  ...           0.646616           0.601637
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 2           0.747583           0.620558           0.867102           0.874865
# 6           0.763514           0.605967           0.894992           0.835461
# 5           0.761392           0.584076           0.885246           0.826280
# 0           0.785467           0.569054           0.904685           0.901464
# 4           0.761392           0.591153           0.894602           0.836363
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 2           0.703659         0.732173        0.086991                1
# 6           0.716813         0.730183        0.086667                2
# 5           0.704160         0.727641        0.084761                3
# 0           0.674859         0.727054        0.104374                4
# 4           0.704160         0.726502        0.092090                5
#
# [5 rows x 22 columns]

# %%
parameters = {  
    'random_state': [42],
    'min_interval': [45],
    'inner_series_length': [1440], 
    'n_estimators': [500],
}

# %%
tsf_grid_final_test = find_best_hyperparameters(tsf, parameters, X, y)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.630 total time= 2.5min
# [CV 2/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.704 total time= 2.3min
# [CV 3/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.725 total time= 2.3min
# [CV 4/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.707 total time= 2.2min
# [CV 5/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.640 total time= 2.1min
# [CV 6/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.781 total time= 2.1min
# [CV 7/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.634 total time= 2.1min
# [CV 8/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.905 total time= 2.9min
# [CV 9/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.875 total time= 3.8min
# [CV 10/10] END inner_series_length=1440, min_interval=45, n_estimators=500, random_state=42;, score=0.704 total time= 3.8min

# %%
display(tsf_grid_final_test.sort_values(by='rank_test_score').head())
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     148.048741     34.999552         8.566427        2.784058
#
#    param_inner_series_length  param_min_interval  param_n_estimators  \
# 0                       1440                  45                 500
#
#    param_random_state                                             params  \
# 0                  42  {'inner_series_length': 1440, 'min_interval': ...
#
#    split0_test_score  ...  split3_test_score  split4_test_score  \
# 0           0.629898  ...           0.706719           0.639595
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.781276           0.634432           0.904685           0.874865
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.70416         0.730442         0.09131                1
#
# [1 rows x 22 columns]

# %%
tsf_grid.to_csv('grid_search_tsf.csv', index=False)

# %% [markdown]
# # ROCKET

# %%
rocket = RocketClassifier()
parameters = {  'random_state': [42],
                'num_kernels': [ 1000, 5000, 10000, 20000, 30000, 40000, 50000 ] }

# %%
rocket_grid = find_best_hyperparameters(rocket, parameters, X, y)
# Out:
# Fitting 10 folds for each of 7 candidates, totalling 70 fits
# [CV 1/10] END num_kernels=1000, random_state=42;, score=0.658 total time=  42.6s
# [CV 2/10] END num_kernels=1000, random_state=42;, score=0.591 total time=  42.8s
# [CV 3/10] END num_kernels=1000, random_state=42;, score=0.765 total time=  38.0s
# [CV 4/10] END num_kernels=1000, random_state=42;, score=0.726 total time=  36.6s
# [CV 5/10] END num_kernels=1000, random_state=42;, score=0.639 total time=  36.8s
# [CV 6/10] END num_kernels=1000, random_state=42;, score=0.777 total time=  37.5s
# [CV 7/10] END num_kernels=1000, random_state=42;, score=0.591 total time=  37.0s
# [CV 8/10] END num_kernels=1000, random_state=42;, score=0.807 total time=  37.9s
# [CV 9/10] END num_kernels=1000, random_state=42;, score=0.776 total time=  36.0s
# [CV 10/10] END num_kernels=1000, random_state=42;, score=0.635 total time=  22.6s
# [CV 1/10] END num_kernels=5000, random_state=42;, score=0.719 total time= 1.3min
# [CV 2/10] END num_kernels=5000, random_state=42;, score=0.583 total time= 1.3min
# [CV 3/10] END num_kernels=5000, random_state=42;, score=0.799 total time= 1.3min
# [CV 4/10] END num_kernels=5000, random_state=42;, score=0.700 total time= 1.3min
# [CV 5/10] END num_kernels=5000, random_state=42;, score=0.658 total time= 1.3min
# [CV 6/10] END num_kernels=5000, random_state=42;, score=0.770 total time= 1.3min
# [CV 7/10] END num_kernels=5000, random_state=42;, score=0.643 total time= 1.3min
# [CV 8/10] END num_kernels=5000, random_state=42;, score=0.864 total time=458.1min
# [CV 9/10] END num_kernels=5000, random_state=42;, score=0.779 total time= 1.3min
# [CV 10/10] END num_kernels=5000, random_state=42;, score=0.633 total time= 1.3min
# [CV 1/10] END num_kernels=10000, random_state=42;, score=0.704 total time= 2.6min
# [CV 2/10] END num_kernels=10000, random_state=42;, score=0.630 total time= 2.6min
# [CV 3/10] END num_kernels=10000, random_state=42;, score=0.828 total time= 2.6min
# [CV 4/10] END num_kernels=10000, random_state=42;, score=0.746 total time= 2.6min
# [CV 5/10] END num_kernels=10000, random_state=42;, score=0.667 total time= 6.3min
# [CV 6/10] END num_kernels=10000, random_state=42;, score=0.759 total time= 2.6min
# [CV 7/10] END num_kernels=10000, random_state=42;, score=0.576 total time= 2.6min
# [CV 8/10] END num_kernels=10000, random_state=42;, score=0.835 total time= 2.6min
# [CV 9/10] END num_kernels=10000, random_state=42;, score=0.715 total time= 2.5min
# [CV 10/10] END num_kernels=10000, random_state=42;, score=0.670 total time= 2.6min
# [CV 1/10] END num_kernels=20000, random_state=42;, score=0.710 total time= 5.4min
# [CV 2/10] END num_kernels=20000, random_state=42;, score=0.613 total time= 5.3min
# [CV 3/10] END num_kernels=20000, random_state=42;, score=0.819 total time= 5.5min
# [CV 4/10] END num_kernels=20000, random_state=42;, score=0.681 total time= 5.5min
# [CV 5/10] END num_kernels=20000, random_state=42;, score=0.639 total time= 5.6min
# [CV 6/10] END num_kernels=20000, random_state=42;, score=0.753 total time= 5.6min
# [CV 7/10] END num_kernels=20000, random_state=42;, score=0.584 total time= 5.5min
# [CV 8/10] END num_kernels=20000, random_state=42;, score=0.827 total time= 5.6min
# [CV 9/10] END num_kernels=20000, random_state=42;, score=0.723 total time= 5.5min
# [CV 10/10] END num_kernels=20000, random_state=42;, score=0.671 total time= 5.5min
# [CV 1/10] END num_kernels=30000, random_state=42;, score=0.634 total time= 8.5min
# [CV 2/10] END num_kernels=30000, random_state=42;, score=0.591 total time= 8.5min
# [CV 3/10] END num_kernels=30000, random_state=42;, score=0.799 total time= 8.5min
# [CV 4/10] END num_kernels=30000, random_state=42;, score=0.709 total time= 8.5min
# [CV 5/10] END num_kernels=30000, random_state=42;, score=0.601 total time= 8.6min
# [CV 6/10] END num_kernels=30000, random_state=42;, score=0.733 total time= 8.5min
# [CV 7/10] END num_kernels=30000, random_state=42;, score=0.555 total time= 8.5min
# [CV 8/10] END num_kernels=30000, random_state=42;, score=0.846 total time= 8.5min
# [CV 9/10] END num_kernels=30000, random_state=42;, score=0.732 total time= 8.5min
# [CV 10/10] END num_kernels=30000, random_state=42;, score=0.679 total time= 8.6min
# [CV 1/10] END num_kernels=40000, random_state=42;, score=0.679 total time=12.5min
# [CV 2/10] END num_kernels=40000, random_state=42;, score=0.591 total time=12.3min
# [CV 3/10] END num_kernels=40000, random_state=42;, score=0.830 total time=11.8min
# [CV 4/10] END num_kernels=40000, random_state=42;, score=0.673 total time=11.8min
# [CV 5/10] END num_kernels=40000, random_state=42;, score=0.649 total time=11.7min
# [CV 6/10] END num_kernels=40000, random_state=42;, score=0.764 total time=11.8min
# [CV 7/10] END num_kernels=40000, random_state=42;, score=0.555 total time=11.7min
# [CV 8/10] END num_kernels=40000, random_state=42;, score=0.837 total time=11.8min
# [CV 9/10] END num_kernels=40000, random_state=42;, score=0.732 total time=19.9min
# [CV 10/10] END num_kernels=40000, random_state=42;, score=0.659 total time=14.5min
# [CV 1/10] END num_kernels=50000, random_state=42;, score=0.675 total time=19.1min
# [CV 2/10] END num_kernels=50000, random_state=42;, score=0.604 total time=19.0min
# [CV 3/10] END num_kernels=50000, random_state=42;, score=0.830 total time=19.1min
# [CV 4/10] END num_kernels=50000, random_state=42;, score=0.696 total time=34.1min
# [CV 5/10] END num_kernels=50000, random_state=42;, score=0.639 total time=174.8min
# [CV 6/10] END num_kernels=50000, random_state=42;, score=0.735 total time=17.8min
# [CV 7/10] END num_kernels=50000, random_state=42;, score=0.548 total time=18.7min
# [CV 8/10] END num_kernels=50000, random_state=42;, score=0.835 total time=17.0min
# [CV 9/10] END num_kernels=50000, random_state=42;, score=0.760 total time=15.9min
# [CV 10/10] END num_kernels=50000, random_state=42;, score=0.650 total time=16.1min

# %%
display(rocket_grid.sort_values(by='rank_test_score').head())
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1    2812.703027   8222.386977         4.820005        0.548711
# 2     166.252612     67.861982        10.130954        0.088238
# 3     305.093170      4.715266        24.694730        0.600827
# 6    1995.961953   2811.597823       113.303735       32.926572
# 5     712.404922    142.151333        66.634522        5.571079
#
#    param_num_kernels  param_random_state  \
# 1               5000                  42
# 2              10000                  42
# 3              20000                  42
# 6              50000                  42
# 5              40000                  42
#
#                                        params  split0_test_score  \
# 1   {'num_kernels': 5000, 'random_state': 42}           0.718823
# 2  {'num_kernels': 10000, 'random_state': 42}           0.703740
# 3  {'num_kernels': 20000, 'random_state': 42}           0.710275
# 6  {'num_kernels': 50000, 'random_state': 42}           0.675053
# 5  {'num_kernels': 40000, 'random_state': 42}           0.678654
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 1           0.583149           0.799159           0.699959           0.657704
# 2           0.629898           0.828356           0.745823           0.666839
# 3           0.612928           0.819243           0.680602           0.638688
# 6           0.603991           0.830161           0.695782           0.639276
# 5           0.590597           0.830161           0.673419           0.648950
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 1           0.770218           0.642878           0.864078           0.778608
# 2           0.758991           0.575917           0.835461           0.714753
# 3           0.752590           0.584076           0.827153           0.723161
# 6           0.735036           0.548416           0.835461           0.760458
# 5           0.763514           0.555308           0.837112           0.732240
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 1           0.632906         0.714748        0.083217                1
# 2           0.669933         0.712971        0.078274                2
# 3           0.671024         0.701974        0.077299                3
# 6           0.650463         0.697410        0.088929                4
# 5           0.658583         0.696854        0.088941                5

# %%
rocket_grid.to_csv('grid_search_rocket.csv', index=False)
